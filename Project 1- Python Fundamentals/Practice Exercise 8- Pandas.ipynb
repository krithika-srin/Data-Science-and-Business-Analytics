# %% [markdown]
# # Pandas

# %% [markdown]
# We have seen Numpy in the last section. It is good at performing math operation on 2d-arrays of numbers. But the major drawback is, it cannot deal with heterogenous values. So, Pandas dataframes are helpful in that aspect for storing different data types and referring the values like a dict in python instead of just referring each item with index.
#
# [Link to Official Documentation](http://pandas.pydata.org/pandas-docs/version/0.23/dsintro.html)

# %% [markdown]
# ## Series

# %% [markdown]
# Pandas series are almost same as nd arrays in numpy, with a additional inferencing ability with custom labels like *keys* in a *dictionary* in python.

# %%
import numpy as np
import pandas as pd

# %%
#Example

series2 = pd.Series(data = [1,2,3], index = ['key1', 'key2', 'key3'])
series2
# Out:
# key1    1
# key2    2
# key3    3
# dtype: int64

# %% [markdown]
# ### Question 1
#
# Convert a given dict to pd series.
#
# [**Hint:** Use **.Series**]

# %%
dict = {'a': 10, 'b': 20, 'c': 30}
series1 = pd.Series(data = [10, 20, 30], index = ['a', 'b', 'c'])
series1
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# You can directly use numpy functions on series.
# ### Question 2
#
# Find the dot product of both the series create above
#
#
# [ **Hint:** Use **np.dot()** ]

# %%
print(np.dot(series1, series2))
# Out:
# 140

# %% [markdown]
# ## Dataframes

# %% [markdown]
# A dataframe is a table with labeled columns which can hold different types of data in each column.

# %%
# Example
d1 = {'a': [1,2,3], 'b': [3,4,5], 'c':[6,7,8] }
df1 = pd.DataFrame(d1)
df1
# Out:
#    a  b  c
# 0  1  3  6
# 1  2  4  7
# 2  3  5  8

# %% [markdown]
# ### Question 3
#
# Select second row in the above dataframe df1.

# %%
# print([df1.loc[1,]])
df1.loc[[1,]]
# Out:
#    a  b  c
# 1  2  4  7

# %% [markdown]
# ### Question 4
#
# Select column c in second row of df1.
#
# [ **Hint:** For using labels use **df.loc[row, column]**. For using numeric indexed use **df.iloc[]**. For using mixture of numeric indexes and labels use **df.ix[row, column]** ]

# %%
# df1.loc[1,'c']
df1.iloc[1,2]
# Out:
# 7

# %% [markdown]
# ## Using Dataframes on a dataset

# %% [markdown]
# ##### Using the mtcars dataset.
#
# For the below set of questions, we will be using the cars data from [Motor Trend Car Road Tests](http://stat.ethz.ch/R-manual/R-devel/library/datasets/html/mtcars.html)
#
# The data was extracted from the 1974 Motor Trend US magazine, and comprises fuel consumption and 10 aspects of automobile design and performance for 32 automobiles (1973–74 models).
#
#
# Details :
#
# A data frame with 32 observations on 11 (numeric) variables.
#
# [, 1] 	mpg 	Miles/(US) gallon
#
# [, 2] 	cyl 	Number of cylinders
#
# [, 3] 	disp 	Displacement (cu.in.)
#
# [, 4] 	hp 	Gross horsepower
#
# [, 5] 	drat 	Rear axle ratio
#
# [, 6] 	wt 	Weight (1000 lbs)
#
# [, 7] 	qsec 	1/4 mile time
#
# [, 8] 	vs 	Engine (0 = V-shaped, 1 = straight)
#
# [, 9] 	am 	Transmission (0 = automatic, 1 = manual)
#
# [,10] 	gear 	Number of forward gears
#
# [,11] 	carb 	Number of carburetors

# %%
## Reading a dataset from a csv file using pandas.

mtcars = pd.read_csv('C:\\Users\\KXS26XY\\OneDrive - The Home Depot\\Desktop\\Data Science and Business Analytics\\mtcars.csv')
mtcars.index = mtcars['name']

# %% [markdown]
# Following questions are based on analysing a particular dataset using dataframes.

# %% [markdown]
# ### Question 5
#
# Check the type and dimensions of given dataset - mtcars.
#
#
# [ **Hint: ** Use **type()** and **df.shape** ]

# %%
# mtcars.head()
type(mtcars)
mtcars.shape
# Out:
# (32, 12)

# %% [markdown]
# ### Question 6
#
# Check the first 10 lines and last 10 lines of the given dataset- mtcars.
#
# [**Hint:** Use **.head()** and **.tail()**]

# %%
# mtcars.head()
mtcars.tail()
# Out:
#                           name   mpg  cyl   disp   hp  drat     wt  qsec  vs  \
# name
# Lotus Europa      Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.9   1
# Ford Pantera L  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0
# Ferrari Dino      Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.5   0
# Maserati Bora    Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0
# Volvo 142E          Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.6   1
#
#                 am  gear  carb
# name
# Lotus Europa     1     5     2
# Ford Pantera L   1     5     4
# Ferrari Dino     1     5     6
# Maserati Bora    1     5     8
# Volvo 142E       1     4     2

# %% [markdown]
# ### Question 7
#
# Print all the column labels in the given dataset - mtcars.
#
# [ **Hint: ** Use **df.columns** ]

# %%
mtcars.columns
# Out:
# Index(['name', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %% [markdown]
# ### Question 8

# %% [markdown]
# Select first 6 rows and 3 columns in mtcars dataframe.
#
# **Hint: **
# mtcars.iloc[:,:] gives all rows and columns in the dataset.

# %%
mtcars.iloc[:6, :3]
# Out:
#                                 name   mpg  cyl
# name
# Mazda RX4                  Mazda RX4  21.0    6
# Mazda RX4 Wag          Mazda RX4 Wag  21.0    6
# Datsun 710                Datsun 710  22.8    4
# Hornet 4 Drive        Hornet 4 Drive  21.4    6
# Hornet Sportabout  Hornet Sportabout  18.7    8
# Valiant                      Valiant  18.1    6

# %% [markdown]
# ### Question 9

# %% [markdown]
# Select rows from name **Mazda RX4** to **Valiant** in the mtcars dataset and display only mpg and cyl values of those cars.
#
# **Hint:** Use df **.iloc[rows,columns]**

# %%
mtcars.loc['Mazda RX4':'Valiant', 'mpg':'cyl']
# Out:
#                     mpg  cyl
# name
# Mazda RX4          21.0    6
# Mazda RX4 Wag      21.0    6
# Datsun 710         22.8    4
# Hornet 4 Drive     21.4    6
# Hornet Sportabout  18.7    8
# Valiant            18.1    6

# %% [markdown]
# ### Question 10
#
# - Sort the dataframe by mpg (i.e. miles/gallon).
# - Hint: Use sort_values() function.

# %%
mtcars.sort_values(by=['mpg'], ascending=False, inplace=False)
# Out:
#                                     name   mpg  cyl   disp   hp  drat     wt  \
# name
# Toyota Corolla            Toyota Corolla  33.9    4   71.1   65  4.22  1.835
# Fiat 128                        Fiat 128  32.4    4   78.7   66  4.08  2.200
# Lotus Europa                Lotus Europa  30.4    4   95.1  113  3.77  1.513
# Honda Civic                  Honda Civic  30.4    4   75.7   52  4.93  1.615
# Fiat X1-9                      Fiat X1-9  27.3    4   79.0   66  4.08  1.935
# Porsche 914-2              Porsche 914-2  26.0    4  120.3   91  4.43  2.140
# Merc 240D                      Merc 240D  24.4    4  146.7   62  3.69  3.190
# Datsun 710                    Datsun 710  22.8    4  108.0   93  3.85  2.320
# Merc 230                        Merc 230  22.8    4  140.8   95  3.92  3.150
# Toyota Corona              Toyota Corona  21.5    4  120.1   97  3.70  2.465
# Volvo 142E                    Volvo 142E  21.4    4  121.0  109  4.11  2.780
# ...

# %%
a = ['x', 'y', 'z']
b = ['w']
a.append(b)
print(a)
# Out:
# ['x', 'y', 'z', ['w']]

# %%
a = ('x', 'y', 'z')

a[0] = 't'

print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-f61ae51e092f> in <module>
#       1 a = ('x', 'y', 'z')
#       2
# ----> 3 a[0] = 't'
#       4
#       5 print(a)
#
# TypeError: 'tuple' object does not support item assignment

# %%
x = 1

for i in range(1,10,2):

    print(x*i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
import pandas as pd

match_data = pd.read_csv('C:\\Users\\KXS26XY\\OneDrive - The Home Depot\\Desktop\\Data Science and Business Analytics\\match_data.csv')
match_data.head()
# Out:
#        id  season    city        date                        team1  \
# 0  419164    2010  Mumbai  2010-04-24  Royal Challengers Bangalore
# 1  419131    2010   Delhi  2010-03-29             Delhi Daredevils
# 2  336021    2008  Mumbai  2008-05-16               Mumbai Indians
# 3  980931    2016    Pune  2016-04-22      Rising Pune Supergiants
# 4  419163    2010  Mumbai  2010-04-22          Chennai Super Kings
#
#                          team2              toss_winner toss_decision  \
# 0              Deccan Chargers          Deccan Chargers           bat
# 1        Kolkata Knight Riders         Delhi Daredevils           bat
# 2        Kolkata Knight Riders           Mumbai Indians         field
# 3  Royal Challengers Bangalore  Rising Pune Supergiants         field
# 4              Deccan Chargers      Chennai Super Kings           bat
#
#                         winner eliminator  ... overs  player_of_match  \
# ...

# %%
match_data.groupby(['city']).count()
# Out:
#                 id  season  date  team1  team2  toss_winner  toss_decision  \
# city
# Abu Dhabi        7       7     7      7      7            7              7
# Ahmedabad       12      12    12     12     12           12             12
# Bangalore       66      66    66     66     66           66             66
# Bengaluru       13      13    13     13     13           13             13
# Bloemfontein     2       2     2      2      2            2              2
# Cape Town        7       7     7      7      7            7              7
# Centurion       12      12    12     12     12           12             12
# Chandigarh      54      54    54     54     54           54             54
# Chennai         56      56    56     56     56           56             56
# Cuttack          7       7     7      7      7            7              7
# Delhi           73      73    73     73     73           73             73
# ...

# %%
match_data_sharjah = match_data[match_data['City'] == 'Sharjah']
match_data_sharjah.head()

match_data_sharjah.groupby(['winner']).count()
# Out:
#                               id  season  city  date  team1  team2  \
# winner
# Chennai Super Kings           99      99    96    99     99     99
# Deccan Chargers               29      29    29    29     29     29
# Delhi Capitals                 7       7     7     7      7      7
# Delhi Daredevils              67      67    65    67     67     67
# Gujarat Lions                 13      13    13    13     13     13
# Kings XI Punjab               79      79    76    79     79     79
# Kochi Tuskers Kerala           6       6     6     6      6      6
# Kolkata Knight Riders         91      91    90    91     91     91
# Mumbai Indians               104     104   104   104    104    104
# Pune Warriors                 12      12    12    12     12     12
# Rajasthan Royals              73      73    73    73     73     73
# Rising Pune Supergiant        10      10    10    10     10     10
# Rising Pune Supergiants        5       5     5     5      5      5
# ...

# %%
match_data.groupby('date').count() == 6
# Out:
#                id  season   city  team1  team2  toss_winner  toss_decision  \
# date
# 2008-04-18  False   False  False  False  False        False          False
# 2008-04-19  False   False  False  False  False        False          False
# 2008-04-20  False   False  False  False  False        False          False
# 2008-04-21  False   False  False  False  False        False          False
# 2008-04-22  False   False  False  False  False        False          False
# ...           ...     ...    ...    ...    ...          ...            ...
# 2019-04-27  False   False  False  False  False        False          False
# 2019-04-28  False   False  False  False  False        False          False
# 2019-04-29  False   False  False  False  False        False          False
# 2019-04-30  False   False  False  False  False        False          False
# 2019-05-01  False   False  False  False  False        False          False
#
# ...
